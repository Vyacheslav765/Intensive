# %%
import cianparser

moscow_parser = cianparser.CianParser(location="Москва")
data = moscow_parser.get_flats(deal_type="sale", rooms=1, with_saving_csv=True, with_extra_data=True, additional_settings={"start_page":1, "end_page":54})

print(data[0])
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# d:\Visual Studio Code\ParsingCian\CianParsing\cian_flat_sale_1_54_moskva_25_Oct_2024_19_06_05_030032.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 2 %. Average price: 195 542 571 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 2 %. Average price: 195 542 571 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 2 %. Average price: 195 542 571 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308812807/
# The collection of information from the pages with ending parse on 1 page...
#
#
#  2 page: 28 offers
#  2 | 2 page with list: [=>                                                      ] 4% | Count of all parsed: 26. Progress ratio: 2 %. Average price: 196 092 571 rub
#  2 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307942491/
# The collection of information from the pages with ending parse on 2 page...
#
#
#  3 page: 28 offers
#  3 | 3 page with list: [=>                                                      ] 4% | Count of all parsed: 27. Progress ratio: 2 %. Average price: 196 395 904 rub
#  3 | 3 page with list: [=>                                                      ] 4% | Count of all parsed: 27. Progress ratio: 2 %. Average price: 196 395 904 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305778449/
# The collection of information from the pages with ending parse on 3 page...
#
#
#  4 page: 28 offers
#  4 | 4 page with list: [=>                                                      ] 4% | Count of all parsed: 28. Progress ratio: 2 %. Average price: 197 972 833 rub
#  4 | 4 page with list: [=>                                                      ] 4% | Count of all parsed: 28. Progress ratio: 2 %. Average price: 197 972 833 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305881394/
# The collection of information from the pages with ending parse on 4 page...
#
#
#  5 page: 28 offers
#  5 | 5 page with list: [=>                                                      ] 4% | Count of all parsed: 29. Progress ratio: 2 %. Average price: 199 052 143 rub
#  5 | 5 page with list: [=>                                                      ] 4% | Count of all parsed: 29. Progress ratio: 2 %. Average price: 199 052 143 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/296193001/
# The collection of information from the pages with ending parse on 5 page...
#
#
#  6 page: 28 offers
#  6 | 6 page with list: [=>                                                      ] 4% | Count of all parsed: 30. Progress ratio: 2 %. Average price: 199 498 810 rub
#  6 | 6 page with list: [=>                                                      ] 4% | Count of all parsed: 30. Progress ratio: 2 %. Average price: 199 498 810 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/306869031/
# The collection of information from the pages with ending parse on 6 page...
#
#
#  7 page: 28 offers
#  7 | 7 page with list: [=>                                                      ] 4% | Count of all parsed: 31. Progress ratio: 3 %. Average price: 200 023 391 rub
#  7 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307689423/
# The collection of information from the pages with ending parse on 7 page...
#
#
#  8 page: 28 offers
#  8 | 8 page with list: [=>                                                      ] 4% | Count of all parsed: 32. Progress ratio: 3 %. Average price: 200 656 204 rub
#  8 | 8 page with list: [=>                                                      ] 4% | Count of all parsed: 32. Progress ratio: 3 %. Average price: 200 656 204 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308305236/
# The collection of information from the pages with ending parse on 8 page...
#
#
#  9 page: 28 offers
#  9 | 9 page with list: [=>                                                      ] 4% | Count of all parsed: 33. Progress ratio: 3 %. Average price: 200 897 113 rub
#  9 | 9 page with list: [=>                                                      ] 4% | Count of all parsed: 33. Progress ratio: 3 %. Average price: 200 897 113 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/303859440/
# The collection of information from the pages with ending parse on 9 page...
#
#
#  10 | 10 page with list: [=>                                                      ] 4% | Count of all parsed: 33. Progress ratio: 3 %. Average price: 200 897 113 rub
#  10 | 10 page with list: [=>                                                      ] 4% | Count of all parsed: 33. Progress ratio: 3 %. Average price: 200 897 113 rub
#
# Exception: 500 Server Error: Internal Server Error for url: https://www.cian.ru/cat.php?engine_version=2&p=10&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 10 page...
#
#
#  11 | 11 page with list: [=>                                                      ] 4% | Count of all parsed: 34. Progress ratio: 3 %. Average price: 201 835 348 rub
#  11 | 11 page with list: [=>                                                      ] 4% | Count of all parsed: 34. Progress ratio: 3 %. Average price: 201 835 348 rub
#  11 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307866179/
# The collection of information from the pages with ending parse on 11 page...
#
#
#  12 | 12 page with list: [=>                                                      ] 4% | Count of all parsed: 35. Progress ratio: 3 %. Average price: 202 161 062 rub
#  12 page: 28 offers
#  12 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307592885/
# The collection of information from the pages with ending parse on 12 page...
#
#
#  13 | 13 page with list: [=>                                                      ] 4% | Count of all parsed: 36. Progress ratio: 3 %. Average price: 202 409 083 rub
#  13 | 13 page with list: [=>                                                      ] 4% | Count of all parsed: 36. Progress ratio: 3 %. Average price: 202 409 083 rub
#  13 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308704187/
# The collection of information from the pages with ending parse on 13 page...
#
#
#  14 | 14 page with list: [=>                                                      ] 4% | Count of all parsed: 37. Progress ratio: 3 %. Average price: 202 909 083 rub
#  14 | 14 page with list: [=>                                                      ] 4% | Count of all parsed: 37. Progress ratio: 3 %. Average price: 202 909 083 rub
#  14 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/298068853/
# The collection of information from the pages with ending parse on 14 page...
#
#
#  15 | 15 page with list: [=>                                                      ] 4% | Count of all parsed: 38. Progress ratio: 3 %. Average price: 203 206 188 rub
#  15 | 15 page with list: [=>                                                      ] 4% | Count of all parsed: 38. Progress ratio: 3 %. Average price: 203 206 188 rub
#  15 | 15 page with list: [=>                                                      ] 4% | Count of all parsed: 38. Progress ratio: 3 %. Average price: 203 206 188 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307788203/
# The collection of information from the pages with ending parse on 15 page...
#
#
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 39. Progress ratio: 3 %. Average price: 203 333 111 rub
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 39. Progress ratio: 3 %. Average price: 203 333 111 rub
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 39. Progress ratio: 3 %. Average price: 203 333 111 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305918006/
# The collection of information from the pages with ending parse on 16 page...
#
#
#  17 page: 28 offers
#  17 | 17 page with list: [=>                                                      ] 4% | Count of all parsed: 40. Progress ratio: 3 %. Average price: 203 533 111 rub
#  17 | 17 page with list: [=>                                                      ] 4% | Count of all parsed: 40. Progress ratio: 3 %. Average price: 203 533 111 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/306546518/
# The collection of information from the pages with ending parse on 17 page...
#
#
#  18 page: 28 offers
#  18 | 18 page with list: [=>                                                      ] 4% | Count of all parsed: 41. Progress ratio: 3 %. Average price: 203 754 392 rub
#  18 | 18 page with list: [=>                                                      ] 4% | Count of all parsed: 41. Progress ratio: 3 %. Average price: 203 754 392 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308300378/
# The collection of information from the pages with ending parse on 18 page...
#
#
#  19 page: 28 offers
#  19 | 19 page with list: [=>                                                      ] 4% | Count of all parsed: 42. Progress ratio: 3 %. Average price: 203 990 106 rub
#  19 | 19 page with list: [=>                                                      ] 4% | Count of all parsed: 42. Progress ratio: 3 %. Average price: 203 990 106 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/303544993/
# The collection of information from the pages with ending parse on 19 page...
#
#
#  20 page: 28 offers
#  20 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=20&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 20 page...
#
#
#  21 | 21 page with list: [=>                                                      ] 4% | Count of all parsed: 43. Progress ratio: 3 %. Average price: 204 261 036 rub
#  21 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=21&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 21 page...
#
#
#  22 | 22 page with list: [=>                                                      ] 4% | Count of all parsed: 44. Progress ratio: 3 %. Average price: 204 576 945 rub
#  22 | 22 page with list: [=>                                                      ] 4% | Count of all parsed: 44. Progress ratio: 3 %. Average price: 204 576 945 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305427316/
# The collection of information from the pages with ending parse on 22 page...
#
#
#  23 | 23 page with list: [=>                                                      ] 4% | Count of all parsed: 45. Progress ratio: 3 %. Average price: 204 963 612 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/306939500/
# The collection of information from the pages with ending parse on 23 page...
#
#
#  24 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=24&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 24 page...
#
#
#  25 | 25 page with list: [=>                                                      ] 4% | Count of all parsed: 46. Progress ratio: 4 %. Average price: 205 528 830 rub
#  25 | 25 page with list: [=>=>                                                    ] 8% | Count of all parsed: 47. Progress ratio: 4 %. Average price: 206 095 406 rub
#  25 | 25 page with list: [=>=>                                                    ] 8% | Count of all parsed: 47. Progress ratio: 4 %. Average price: 206 095 406 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307798581/
# The collection of information from the pages with ending parse on 25 page...
#
#
#  26 | 26 page with list: [=>                                                      ] 4% | Count of all parsed: 48. Progress ratio: 4 %. Average price: 206 175 927 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308633404/
# The collection of information from the pages with ending parse on 26 page...
#
#
#  27 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=27&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 27 page...
#
#
#  28 | 28 page with list: [=>                                                      ] 4% | Count of all parsed: 49. Progress ratio: 4 %. Average price: 206 319 127 rub
#  28 | 28 page with list: [=>                                                      ] 4% | Count of all parsed: 49. Progress ratio: 4 %. Average price: 206 319 127 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=28&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 28 page...
#
#
#  29 | 29 page with list: [=>                                                      ] 4% | Count of all parsed: 50. Progress ratio: 4 %. Average price: 206 464 206 rub
#  29 | 29 page with list: [=>                                                      ] 4% | Count of all parsed: 50. Progress ratio: 4 %. Average price: 206 464 206 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/306969594/
# The collection of information from the pages with ending parse on 29 page...
#
#
#  30 | 30 page with list: [=>                                                      ] 4% | Count of all parsed: 51. Progress ratio: 4 %. Average price: 206 610 343 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/304612074/
# The collection of information from the pages with ending parse on 30 page...
#
#
#  31 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=31&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 31 page...
#
#
#  32 | 32 page with list: [=>                                                      ] 4% | Count of all parsed: 52. Progress ratio: 4 %. Average price: 206 758 221 rub
#  32 | 32 page with list: [=>                                                      ] 4% | Count of all parsed: 52. Progress ratio: 4 %. Average price: 206 758 221 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=32&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 32 page...
#
#
#  33 | 33 page with list: [=>                                                      ] 4% | Count of all parsed: 53. Progress ratio: 4 %. Average price: 206 904 795 rub
#  33 | 33 page with list: [=>                                                      ] 4% | Count of all parsed: 53. Progress ratio: 4 %. Average price: 206 904 795 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/303687714/
# The collection of information from the pages with ending parse on 33 page...
#
#
#  34 | 34 page with list: [=>                                                      ] 4% | Count of all parsed: 54. Progress ratio: 4 %. Average price: 207 051 805 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308966797/
# The collection of information from the pages with ending parse on 34 page...
#
#
#  35 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=35&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 35 page...
#
#
#  36 | 36 page with list: [=>                                                      ] 4% | Count of all parsed: 55. Progress ratio: 4 %. Average price: 207 200 893 rub
#  36 | 36 page with list: [=>=>                                                    ] 8% | Count of all parsed: 56. Progress ratio: 4 %. Average price: 207 347 427 rub
#  36 | 36 page with list: [=>=>                                                    ] 8% | Count of all parsed: 56. Progress ratio: 4 %. Average price: 207 347 427 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308762119/
# The collection of information from the pages with ending parse on 36 page...
#
#
#  37 | 37 page with list: [=>                                                      ] 4% | Count of all parsed: 57. Progress ratio: 4 %. Average price: 207 494 049 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308657156/
# The collection of information from the pages with ending parse on 37 page...
#
#
#  38 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=38&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 38 page...
#
#
#  39 | 39 page with list: [=>                                                      ] 4% | Count of all parsed: 58. Progress ratio: 4 %. Average price: 207 640 868 rub
#  39 | 39 page with list: [=>                                                      ] 4% | Count of all parsed: 58. Progress ratio: 4 %. Average price: 207 640 868 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=39&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 39 page...
#
#
#  40 | 40 page with list: [=>                                                      ] 4% | Count of all parsed: 59. Progress ratio: 4 %. Average price: 207 786 428 rub
#  40 | 40 page with list: [=>                                                      ] 4% | Count of all parsed: 59. Progress ratio: 4 %. Average price: 207 786 428 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308966838/
# The collection of information from the pages with ending parse on 40 page...
#
#
#  41 | 41 page with list: [=>                                                      ] 4% | Count of all parsed: 60. Progress ratio: 4 %. Average price: 207 930 734 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/299212905/
# The collection of information from the pages with ending parse on 41 page...
#
#
#  42 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=42&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 42 page...
#
#
#  43 | 43 page with list: [=>                                                      ] 4% | Count of all parsed: 61. Progress ratio: 5 %. Average price: 208 077 907 rub
#  43 | 43 page with list: [=>                                                      ] 4% | Count of all parsed: 61. Progress ratio: 5 %. Average price: 208 077 907 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=43&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 43 page...
#
#
#  44 | 44 page with list: [=>                                                      ] 4% | Count of all parsed: 62. Progress ratio: 5 %. Average price: 208 222 651 rub
#  44 | 44 page with list: [=>                                                      ] 4% | Count of all parsed: 62. Progress ratio: 5 %. Average price: 208 222 651 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307868535/
# The collection of information from the pages with ending parse on 44 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=45&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 45 page...
#
#
#  46 | 46 page with list: [=>                                                      ] 4% | Count of all parsed: 63. Progress ratio: 5 %. Average price: 208 368 119 rub
#  46 | 46 page with list: [=>=>                                                    ] 8% | Count of all parsed: 64. Progress ratio: 5 %. Average price: 208 511 577 rub
#  46 | 46 page with list: [=>=>                                                    ] 8% | Count of all parsed: 64. Progress ratio: 5 %. Average price: 208 511 577 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/303687858/
# The collection of information from the pages with ending parse on 46 page...
#
#
#  47 | 47 page with list: [=>                                                      ] 4% | Count of all parsed: 65. Progress ratio: 5 %. Average price: 208 653 943 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/304053613/
# The collection of information from the pages with ending parse on 47 page...
#
#
#  48 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=48&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 48 page...
#
#
#  49 | 49 page with list: [=>                                                      ] 4% | Count of all parsed: 66. Progress ratio: 5 %. Average price: 208 798 479 rub
#  49 | 49 page with list: [=>                                                      ] 4% | Count of all parsed: 66. Progress ratio: 5 %. Average price: 208 798 479 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=49&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 49 page...
#
#
#  50 | 50 page with list: [=>                                                      ] 4% | Count of all parsed: 67. Progress ratio: 5 %. Average price: 208 942 067 rub
#  50 | 50 page with list: [=>                                                      ] 4% | Count of all parsed: 67. Progress ratio: 5 %. Average price: 208 942 067 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/303687758/
# The collection of information from the pages with ending parse on 50 page...
#
#
#  51 | 51 page with list: [=>                                                      ] 4% | Count of all parsed: 68. Progress ratio: 5 %. Average price: 209 084 714 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307207384/
# The collection of information from the pages with ending parse on 51 page...
#
#
#  52 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=52&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 52 page...
#
#
#  53 | 53 page with list: [=>                                                      ] 4% | Count of all parsed: 69. Progress ratio: 5 %. Average price: 209 228 592 rub
#  53 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=53&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 53 page...
#
#
#  54 | 54 page with list: [=>                                                ] 4% | Count of all parsed: 70. Progress ratio: 6 %. Average price: 209 371 734 rub
#  54 | 54 page with list: [=>                                                ] 4% | Count of all parsed: 70. Progress ratio: 6 %. Average price: 209 371 734 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305378064/
# The collection of information from the pages with ending parse on 54 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 70.
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# d:\Visual Studio Code\ParsingCian\CianParsing\cian_flat_sale_1_54_moskva_25_Oct_2024_20_00_28_523904.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
#  1 | 1 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 117 936 000 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305768574/
# The collection of information from the pages with ending parse on 1 page...
#
#
#  2 | 2 page with list: [=>                                                      ] 4% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 125 086 000 rub
#  2 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 2 page...
#
#
#  3 | 3 page with list: [=>                                                      ] 4% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 129 652 666 rub
#  3 | 3 page with list: [=>                                                      ] 4% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 129 652 666 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305778449/
# The collection of information from the pages with ending parse on 3 page...
#
#
#  4 | 4 page with list: [=>                                                      ] 4% | Count of all parsed: 4. Progress ratio: 1 %. Average price: 136 057 969 rub
#  4 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/304453140/
# The collection of information from the pages with ending parse on 4 page...
#
#
#  5 | 5 page with list: [=>                                                      ] 4% | Count of all parsed: 5. Progress ratio: 1 %. Average price: 142 317 969 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/299789842/
# The collection of information from the pages with ending parse on 5 page...
#
#
#  6 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=6&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 6 page...
#
#
#  7 | 7 page with list: [=>                                                      ] 4% | Count of all parsed: 6. Progress ratio: 1 %. Average price: 145 028 307 rub
#  7 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=7&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 7 page...
#
#
#  8 | 8 page with list: [=>                                                      ] 4% | Count of all parsed: 7. Progress ratio: 1 %. Average price: 147 921 164 rub
#  8 | 8 page with list: [=>                                                      ] 4% | Count of all parsed: 7. Progress ratio: 1 %. Average price: 147 921 164 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305636955/
# The collection of information from the pages with ending parse on 8 page...
#
#
#  9 | 9 page with list: [=>                                                      ] 4% | Count of all parsed: 8. Progress ratio: 1 %. Average price: 148 914 914 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/303859440/
# The collection of information from the pages with ending parse on 9 page...
#
#
#  10 | 10 page with list: [=>=>                                                    ] 8% | Count of all parsed: 9. Progress ratio: 1 %. Average price: 150 000 470 rub
#  10 | 10 page with list: [=>                                                      ] 4% | Count of all parsed: 9. Progress ratio: 1 %. Average price: 150 000 470 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=10&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 10 page...
#
#
#  11 | 11 page with list: [=>                                                      ] 4% | Count of all parsed: 10. Progress ratio: 1 %. Average price: 153 190 470 rub
#  11 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=11&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 11 page...
#
#
#  12 | 12 page with list: [=>                                                      ] 4% | Count of all parsed: 11. Progress ratio: 1 %. Average price: 154 971 971 rub
#  12 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/304629167/
# The collection of information from the pages with ending parse on 12 page...
#
#
#  13 | 13 page with list: [=>                                                      ] 4% | Count of all parsed: 12. Progress ratio: 1 %. Average price: 155 716 033 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/299010726/
# The collection of information from the pages with ending parse on 13 page...
#
#
#  14 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=14&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 14 page...
#
#
#  15 | 15 page with list: [=>                                                      ] 4% | Count of all parsed: 13. Progress ratio: 1 %. Average price: 156 584 495 rub
#  15 | 15 page with list: [=>                                                      ] 4% | Count of all parsed: 13. Progress ratio: 1 %. Average price: 156 584 495 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=15&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 15 page...
#
#
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 14. Progress ratio: 1 %. Average price: 156 943 781 rub
#  16 | 16 page with list: [=>                                                      ] 4% | Count of all parsed: 14. Progress ratio: 1 %. Average price: 156 943 781 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/300106265/
# The collection of information from the pages with ending parse on 16 page...
#
#
#  17 | 17 page with list: [=>                                                      ] 4% | Count of all parsed: 15. Progress ratio: 1 %. Average price: 157 477 114 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307567475/
# The collection of information from the pages with ending parse on 17 page...
#
#
#  18 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=18&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 18 page...
#
#
#  19 | 19 page with list: [=>                                                      ] 4% | Count of all parsed: 16. Progress ratio: 2 %. Average price: 158 102 114 rub
#  19 | 19 page with list: [=>=>                                                    ] 8% | Count of all parsed: 17. Progress ratio: 2 %. Average price: 158 690 349 rub
#  19 | 19 page with list: [=>=>                                                    ] 8% | Count of all parsed: 17. Progress ratio: 2 %. Average price: 158 690 349 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308057609/
# The collection of information from the pages with ending parse on 19 page...
#
#
#  20 | 20 page with list: [=>                                                      ] 4% | Count of all parsed: 18. Progress ratio: 2 %. Average price: 159 273 127 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/307435904/
# The collection of information from the pages with ending parse on 20 page...
#
#
#  21 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=21&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 21 page...
#
#
#  22 | 22 page with list: [=>                                                      ] 4% | Count of all parsed: 19. Progress ratio: 2 %. Average price: 160 009 969 rub
#  22 | 22 page with list: [=>                                                      ] 4% | Count of all parsed: 19. Progress ratio: 2 %. Average price: 160 009 969 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=22&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# The collection of information from the pages with ending parse on 22 page...
#
#
#  23 | 23 page with list: [=>                                                      ] 4% | Count of all parsed: 20. Progress ratio: 2 %. Average price: 160 909 969 rub
#  23 | 23 page with list: [=>                                                      ] 4% | Count of all parsed: 20. Progress ratio: 2 %. Average price: 160 909 969 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/299651741/
# The collection of information from the pages with ending parse on 23 page...
#
#
#  24 | 24 page with list: [=>                                                      ] 4% | Count of all parsed: 21. Progress ratio: 2 %. Average price: 161 886 160 rub
#
# Exception: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# The collection of information from the pages with ending parse on 24 page...
#
#
#  25 page: 28 offers
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 while a < 30:
#       5     moscow_parser = cianparser.CianParser(location="Москва")
# ----> 6     data = moscow_parser.get_flats(deal_type="sale", rooms=1, with_saving_csv=True, with_extra_data=True, additional_settings={"start_page":1, "end_page":54})
#       7     a=a+1
#       9 print(data[0])
#
# File c:\Users\slava\AppData\Local\Programs\Python\Python312\Lib\site-packages\cianparser\cianparser.py:119, in CianParser.get_flats(self, deal_type, rooms, with_saving_csv, with_extra_data, additional_settings)
#     108 deal_type, rent_period_type = __define_deal_type__(deal_type)
#     109 self.__parser__ = FlatListPageParser(
#     110     session=self.__session__,
#     111     accommodation_type="flat",
#    (...)
#     117     additional_settings=additional_settings,
#     118 )
# --> 119 self.__run__(
#     120     __build_url_list__(location_id=self.__location_id__, deal_type=deal_type, accommodation_type="flat",
#     121                        rooms=rooms, rent_period_type=rent_period_type,
#     122                        additional_settings=additional_settings))
#     123 return self.__parser__.result
#
# File c:\Users\slava\AppData\Local\Programs\Python\Python312\Lib\site-packages\cianparser\cianparser.py:75, in CianParser.__run__(self, url_list_format)
#      73 while attempt_number_exception < 3 and not page_parsed:
#      74     try:
# ---> 75         (page_parsed, attempt_number, end_all_parsing) = self.__parser__.parse_list_offers_page(
#      76             html=self.__load_list_page__(url_list_format=url_list_format, page_number=page_number, attempt_number_exception=attempt_number_exception),
#      77             page_number=page_number,
#      78             count_of_pages=self.__parser__.end_page + 1 - self.__parser__.start_page,
#      79             attempt_number=attempt_number_exception)
#      81     except Exception as e:
#      82         attempt_number_exception += 1
#
# File c:\Users\slava\AppData\Local\Programs\Python\Python312\Lib\site-packages\cianparser\flat\list.py:38, in FlatListPageParser.parse_list_offers_page(self, html, page_number, count_of_pages, attempt_number)
#      35     print(f"Collecting information from pages with list of offers", end="\n")
#      37 for ind, offer in enumerate(offers):
# ---> 38     self.parse_offer(offer=offer)
#      39     self.print_parse_progress(page_number=page_number, count_of_pages=count_of_pages, offers=offers, ind=ind)
#      41 time.sleep(2)
#
# File c:\Users\slava\AppData\Local\Programs\Python\Python312\Lib\site-packages\cianparser\flat\list.py:64, in FlatListPageParser.parse_offer(self, offer)
#      62     flat_parser = FlatPageParser(session=self.session, url=common_data["url"])
#      63     page_data = flat_parser.parse_page()
# ---> 64     time.sleep(20)
#      66 self.count_parsed_offers += 1
#      67 self.define_average_price(price_data=price_data)
#
# KeyboardInterrupt:
